# %% [markdown]
# <a href="https://colab.research.google.com/github/bilgekisi96/My_Data_Science_Advanture/blob/master/DV_capstone_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
df=pd.read_csv("store_sharing.csv")
df.head(25)
# Out:
#               timestamp   cnt   t1  ...  is_holiday  is_weekend  season
# 0   2015-01-04 00:00:00   182  3.0  ...         0.0         1.0     3.0
# 1   2015-01-04 01:00:00   138  3.0  ...         0.0         1.0     3.0
# 2   2015-01-04 02:00:00   134  2.5  ...         0.0         1.0     3.0
# 3   2015-01-04 03:00:00    72  2.0  ...         0.0         1.0     3.0
# 4   2015-01-04 04:00:00    47  2.0  ...         0.0         1.0     3.0
# 5   2015-01-04 05:00:00    46  2.0  ...         0.0         1.0     3.0
# 6   2015-01-04 06:00:00    51  1.0  ...         0.0         1.0     3.0
# 7   2015-01-04 07:00:00    75  1.0  ...         0.0         1.0     3.0
# 8   2015-01-04 08:00:00   131  1.5  ...         0.0         1.0     3.0
# 9   2015-01-04 09:00:00   301  2.0  ...         0.0         1.0     3.0
# 10  2015-01-04 10:00:00   528  3.0  ...         0.0         1.0     3.0
# 11  2015-01-04 11:00:00   727  2.0  ...         0.0         1.0     3.0
# 12  2015-01-04 12:00:00   862  2.0  ...         0.0         1.0     3.0
# 13  2015-01-04 13:00:00   916  3.0  ...         0.0         1.0     3.0
# 14  2015-01-04 14:00:00  1039  2.5  ...         0.0         1.0     3.0
# 15  2015-01-04 15:00:00   869  2.0  ...         0.0         1.0     3.0
# 16  2015-01-04 16:00:00   737  3.0  ...         0.0         1.0     3.0
# 17  2015-01-04 17:00:00   594  3.0  ...         0.0         1.0     3.0
# 18  2015-01-04 18:00:00   522  3.0  ...         0.0         1.0     3.0
# 19  2015-01-04 19:00:00   379  3.0  ...         0.0         1.0     3.0
# 20  2015-01-04 20:00:00   328  3.0  ...         0.0         1.0     3.0
# 21  2015-01-04 21:00:00   221  3.0  ...         0.0         1.0     3.0
# 22  2015-01-04 22:00:00   178  3.0  ...         0.0         1.0     3.0
# 23  2015-01-04 23:00:00   157  4.0  ...         0.0         1.0     3.0
# 24  2015-01-05 00:00:00    83  4.0  ...         0.0         0.0     3.0
#
# [25 rows x 10 columns]

# %%
sns.countplot("season",data=df)
plt.show()

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
df.isnull().value_counts()
# Out:
# timestamp  cnt    t1     t2     hum    wind_speed  weather_code  is_holiday  is_weekend  season
# False      False  False  False  False  False       False         False       False       False     17414
# dtype: int64

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
# season
sns.countplot("season",data=df)
plt.show()

# %%
# is_holiday
sns.countplot("is_holiday",data=df)
plt.show()

# %%
# is_weekend
sns.countplot("is_weekend",data=df)
plt.show()

# %%
# weather_code
sns.countplot("weather_code",data=df)
plt.show()

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
df.timestamp= pd.to_datetime(df.timestamp)
df.set_index("timestamp",inplace=True)

# %% [markdown]
# - Tam 2 yillik bir timestamp var. `year, month, day_of_month, day_of_week, hour` bilgilerini alarak feature engineering yapalim

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %%
df["year"]=df.index.year
df["month"]=df.index.month
df["day_of_week"]=df.index.dayofweek
df["day_of_mounth"]=df.index.dayofyear
df["hour"]=df.index.hour
df["year_month"]=df.index.strftime("%Y-%m")
df
# Out:
#                       cnt   t1   t2  ...  day_of_mounth  hour  year_month
# timestamp                            ...
# 2015-01-04 00:00:00   182  3.0  2.0  ...              4     0     2015-01
# 2015-01-04 01:00:00   138  3.0  2.5  ...              4     1     2015-01
# 2015-01-04 02:00:00   134  2.5  2.5  ...              4     2     2015-01
# 2015-01-04 03:00:00    72  2.0  2.0  ...              4     3     2015-01
# 2015-01-04 04:00:00    47  2.0  0.0  ...              4     4     2015-01
# ...                   ...  ...  ...  ...            ...   ...         ...
# 2017-01-03 19:00:00  1042  5.0  1.0  ...              3    19     2017-01
# 2017-01-03 20:00:00   541  5.0  1.0  ...              3    20     2017-01
# 2017-01-03 21:00:00   337  5.5  1.5  ...              3    21     2017-01
# 2017-01-03 22:00:00   224  5.5  1.5  ...              3    22     2017-01
# 2017-01-03 23:00:00   139  5.0  1.0  ...              3    23     2017-01
#
# [17414 rows x 15 columns]

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
df.head()
# Out:
#                      cnt   t1   t2  ...  day_of_mounth  hour  year_month
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...              4     0     2015-01
# 2015-01-04 01:00:00  138  3.0  2.5  ...              4     1     2015-01
# 2015-01-04 02:00:00  134  2.5  2.5  ...              4     2     2015-01
# 2015-01-04 03:00:00   72  2.0  2.0  ...              4     3     2015-01
# 2015-01-04 04:00:00   47  2.0  0.0  ...              4     4     2015-01
#
# [5 rows x 15 columns]

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
# for all variables 
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,cmap="coolwarm")
plt.show()

# %%
# for the target variable
plt.figure(figsize=(5,6))
sns.heatmap(df.corr()[["cnt"]].sort_values(by="cnt",ascending=False), annot=True, vmin=-1)
plt.show()

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
#with pandas
fig,ax=plt.subplots()
fig.set_size_inches(10.5, 10.5)
ax.barh(list(reversed(df.corrwith(df.cnt).index)),list(reversed(df.corrwith(df.cnt))))
plt.show()

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
plt.figure(figsize=(10,10))
sns.lineplot(x="timestamp",y="cnt",data=df)
plt.show()

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
# with lineplot
plt.figure(figsize=(18,8))
sns.lineplot(x="year_month",y="cnt",data=df)
plt.xticks(rotation=50)
plt.show()

# %%
# with lineplot
plt.figure(figsize=(8,8))
sns.lineplot(x="month",y="cnt",data=df)
#plt.xticks(rotation=50)
plt.show()

# %%
# with pointplot
plt.figure(figsize=(18,4))
sns.pointplot(x ="month", y = "cnt", data = df)
plt.show()

# %%
# with barplot
plt.figure(figsize=(18,6))
sns.barplot(x ="month", y ="cnt", data=df)
plt.show()

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
# with lineplot (*whether it is a holiday or not*)
plt.figure(figsize=(18,6))
sns.lineplot(x = "hour", y="cnt", hue ="is_holiday", data=df)
plt.show()

# %%
# with lineplot (*You may want to see seasonal breakdowns*)
plt.figure(figsize=(18,7))
sns.lineplot(x="hour", y ="cnt", hue ="season", data=df)
plt.show()

# %%
# with pointplot
fig,ax=plt.subplots(4,1,figsize=(18,13))
sns.pointplot(x="hour",y="cnt",data=df,ax=ax[0])
sns.pointplot(x="hour",y="cnt",hue="is_holiday",data=df,ax=ax[1])
sns.pointplot(x="hour",y="cnt",hue="is_weekend",data=df,ax=ax[2])
sns.pointplot(x="hour",y="cnt",hue="season",data=df,ax=ax[3])
plt.show()

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
# with barplot
plt.figure(figsize=(10,8))
sns.barplot(x ="day_of_week", y = "cnt", hue ="is_weekend", data=df)
plt.show()

# %%
# with pointplot
fig, ax = plt.subplots(2,1, figsize=(16,8))

sns.pointplot(x ="day_of_week", y ="cnt",data=df, ax =ax[0])
sns.pointplot(x ="day_of_week", y ="cnt",data=df, ax =ax[1], hue ="season")
plt.show()

# %%
# Out:
# day_of_mounth    1      2      3      4    ...    363    364    365    366
# cnt            234.0  270.0  251.5  425.5  ...  526.0  453.5  411.0  483.5
#
# [1 rows x 366 columns]

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
#with lineplot
plt.figure(figsize=(18,5))
sns.lineplot(x = "day_of_mounth", y ="cnt", data = df )

df.groupby("day_of_mounth")[["cnt"]].median().T
# Out:
# day_of_mounth    1      2      3      4    ...    363    364    365    366
# cnt            234.0  270.0  251.5  425.5  ...  526.0  453.5  411.0  483.5
#
# [1 rows x 366 columns]

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
# with barplot
plt.figure(figsize=(10,6))
sns.barplot(x = "year", y = "cnt", data = df)
plt.show()

# %%
# with barplot
plt.figure(figsize=(10,6))
sns.barplot(x = "season", y = "cnt", data = df[df.is_holiday==1]);
plt.show()

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
df.is_weekend.value_counts()
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
# pie chart
fig, ax = plt.subplots(figsize=(7,7))

plt.pie(df.is_weekend.value_counts(),labels=["weekday","weekend"],labeldistance=0.3,autopct="%0.1f")
plt.show()

# %%
vari = df.is_weekend.value_counts()
list(vari.index)
# Out:
# [0.0, 1.0]

# %%
# with countplot
plt.figure(figsize=(5,6))
sns.countplot(x = "is_weekend",data = df)
for i in range(len(vari)):
    plt.text(list(vari.index)[i], vari[i], str(vari[i]), ha="center",va="bottom",size=9)
plt.show()

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
# with countplot
plt.figure(figsize=(7,6))
sns.countplot(x = "weather_code", data =df)
plt.show()

# %%
# with catplot
plt.figure(figsize=(8,8))
sns.catplot(x="weather_code", data=df, col="season", kind="count")
plt.show()

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
