# %% [markdown]
# ![image%20%286%29.png](attachment:image%20%286%29.png)

# %%
L = [(7,8,3), (3,7,5),(9,1,4),(7,6,2)]
net,bos=int(input("enter index")),[]
test=[j for j in sorted([i[net] for i in L])]
passed=[L[z] for a in test for z in range(len(L)) if a==L[z][net]] 
for gez in passed:
    if gez not in bos:bos.append(gez)
print(bos)
# Out:
# enter index0
# [(3, 7, 5), (7, 8, 3), (7, 6, 2), (9, 1, 4)]
