# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("sales_082020.csv")
df.seller_id.value_counts()
# Out:
# pzsiehl0    703
# wd3rgi3q    525
# j21w87xy    500
# dbm0o9qu    436
# hbtm3tdy    316
#            ...
# 0nbzzk36      1
# tghukb53      1
# 4e4qh5ut      1
# z4m1qi5x      1
# 57wrd0bf      1
# Name: seller_id, Length: 114227, dtype: int64

# %%
df.shape
# Out:
# (237671, 10)

# %%
dfn=df.dropna()
df.category.value_counts()
df[df.currency=="EUR"]
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 546     oagt2ozal7            IE  b57xo98q             IE  2l6ze3xh4roy
# 948     xpbfdqczlk            IT  spoetwqz             IT  ykdmbrywpjx4
# 949     zos594tze5            IT  spoetwqz             IT  vlbfdpb8pke2
# 950     x1bjyofhp5            IT  spoetwqz             IT  ru1iggf0v7rb
# 951     xpbfdqczlk            IT  8b0q1eqs             IT  3hkn59tx2qpi
# ...            ...           ...       ...            ...           ...
# 237579  nnxzdvm374            IE  r0x9jfyv             IE  bbqxlk52za10
# 237596  ho58jlsegc            IE  20cqoo29             IE  unftdfcinfpb
# 237598  svzvwjycr3            IE  u319di3x             IE  rxhpvrtp8je6
# 237634  edj7mhwdm7            IT  jfvp46mm             IT  jy68ug28owl8
# 237642  5b3nv67egk            IT  yprtscow             IT  wuhnmgs9q7me
#
#                 category brand currency   price        date
# ...

# %%
dfn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119324 entries, 1 to 237665
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        119324 non-null  object
#  1   buyer_country   119324 non-null  object
#  2   seller_id       119324 non-null  object
#  3   seller_country  119324 non-null  object
#  4   product_code    119324 non-null  object
#  5   category        119324 non-null  object
#  6   brand           119324 non-null  object
#  7   currency        119324 non-null  object
#  8   price           119324 non-null  float64
#  9   date            119324 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 10.0+ MB
