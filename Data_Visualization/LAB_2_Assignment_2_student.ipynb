# %% [markdown]
# <a href="https://colab.research.google.com/github/bilgekisi96/My_Data_Science_Advanture/blob/master/LAB_2_Assignment_2_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
kill.shape
# Out:
# (2254, 14)

# %%
# Out:
# (2535, 14)

# %%
kill.dropna().shape
# Out:
# (2254, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
np.array(kill.manner_of_death.value_counts().index)

# %%
np.array(kill.manner_of_death.value_counts().index)
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
# with seaborn
sns.boxplot(x="gender",y="age",data=kill,hue="manner_of_death")

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
plt.figure(figsize=(10,10))
sns.swarmplot(x="gender",y="age",data=kill,hue="manner_of_death")

# %%
# with seaborn
plt.figure(figsize=(10,10))
sns.swarmplot(x="gender",y="age",data=kill,hue="manner_of_death")

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
kill.city.value_counts().head(13)
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Tucson           14
# Albuquerque      14
# Oklahoma City    14
# Name: city, dtype: int64

# %%
# Out:
# Los Angeles      35
# Phoenix          28
# Houston          24
# Chicago          22
# Austin           18
# Las Vegas        17
# Columbus         16
# San Antonio      15
# Miami            15
# Indianapolis     14
# St. Louis        14
# Oklahoma City    13
# Name: city, dtype: int64

# %%
fig,ax=plt.subplots(figsize=(8,8))

ax=sns.barplot(x=np.array(kill.city.value_counts().head(13).index),y=kill.city.value_counts().head(13))
plt.xticks(rotation=70)
plt.title("Most Dangereous cities",color="blue",fontsize=30)
plt.show()
killed=pd.DataFrame()
killed["x"]=np.array(kill.city.value_counts().head(13).index)
killed["y"]=np.array(list(kill.city.value_counts().head(13)))

# %%
# with seaborn barplot

# %%
sns.countplot(x="city",data=kill.city.value_counts())
plt.xticks(rotation=70)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-162-07f94fe19c98> in <module>()
#       1
# ----> 2 sns.countplot(x="city",data=kill.city.value_counts())
#       3 plt.xticks(rotation=70)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3600         estimator, ci, n_boot, units, seed,
#    3601         orient, color, palette, saturation,
# -> 3602         errcolor, errwidth, capsize, dodge
#    3603     )
#    3604
#
# ...

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
killed=kill.dropna(inplace=True)
kill.state.value_counts().head(20)
# Out:
# CA    366
# TX    200
# FL    136
# AZ    105
# OH     70
# NC     66
# OK     65
# CO     63
# GA     61
# MO     58
# TN     56
# IL     56
# WA     51
# LA     47
# PA     45
# AL     45
# VA     43
# NY     43
# WI     42
# NM     41
# Name: state, dtype: int64

# %%
# Out:
# CA    366
# TX    200
# FL    136
# AZ    105
# OH     70
# NC     66
# OK     65
# CO     63
# GA     61
# MO     58
# TN     56
# IL     56
# WA     51
# LA     47
# PA     45
# AL     45
# NY     43
# VA     43
# WI     42
# NM     41
# Name: state, dtype: int64

# %%
# with seaborn barplot
sns.barplot(x=kill.state.value_counts().head(20).index,y=kill.state.value_counts().head(20))
plt.title("Most dangerous cities",color="blue",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Most dangerous cities')

# %%
# with seaborn countplot
kill.dropna(inplace=True)
sns.countplot(x=kill.state.value_counts().head(20).index,data=kill)
plt.title("Most dangerous cities",color="blue",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Most dangerous cities')

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
kill.signs_of_mental_illness.value_counts()
# Out:
# False    1681
# True      573
# Name: signs_of_mental_illness, dtype: int64

# %%
# with seaborn
sns.countplot(x="signs_of_mental_illness",data=kill)

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
kill.threat_level.value_counts()
# Out:
# attack          1462
# other            677
# undetermined     115
# Name: threat_level, dtype: int64

# %%
# with seaborn
sns.countplot(x="threat_level",data=kill)

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
kill.flee.value_counts()
# Out:
# Not fleeing    1528
# Car             360
# Foot            278
# Other            88
# Name: flee, dtype: int64

# %%
# with seaborn
sns.countplot(x="flee",data=kill)
