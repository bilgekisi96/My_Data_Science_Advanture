# %%
import pandas as pd
import numpy as np
# Libraries for visualizaton
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig,ax=plt.subplots()
sns.countplot(x="day",data=tips)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+0.5))
    ax.text(p.get_x()+0.1, p.get_height()-3,str(round(p.get_height()/tips.day.count(),2)) )     # yüzdelik ekledik
plt.show()

# %%
ax=sns.countplot(x="day",data=tips,hue="sex")
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.1, p.get_height()+0.3))
    ax.text(p.get_x()+0.1, p.get_height()-3,str(round(p.get_height()/tips.day.count(),2)) )     
    # yüzdelik ekledik
plt.show()

# %%
mpg=sns.load_dataset("mpg")
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.countplot(x="cylinders",data=mpg)
plt.show()

# %%
sns.countplot("model_year",data=mpg)
plt.show()
# Out:
# C:\Users\yavuz\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ax=sns.countplot(x="origin",data=mpg)
for i in ax.patches:
    ax.annotate((i.get_height()), (i.get_x()+0.1, i.get_height()+0.3))
plt.show()

# %%
############--- BARPLOT-----#############

# %%
sns.barplot(x="sex",y="total_bill",data=tips,ci="sd") #ci std sini getirir
plt.show()

# %%
tips.groupby(["day","sex"]).sum()
# Out:
#              total_bill     tip  size
# day  sex
# Thur Male        561.44   89.41    73
#      Female      534.89   82.42    79
# Fri  Male        198.57   26.93    21
#      Female      127.31   25.03    19
# Sat  Male       1227.35  181.95   156
#      Female      551.05   78.45    63
# Sun  Male       1269.46  186.78   163
#      Female      357.70   60.61    53

# %%
sns.barplot(x="day",y="total_bill",data=tips,hue="sex",ci="sd")
plt.show()

# %%
sns.barplot(x="day",y="total_bill",data=tips,hue="sex",ci="sd",estimator=np.sum)
plt.show()#estimator olarak sum unu alıp ona göre yapıyor işlemi

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))
sns.barplot(x="day", y="total_bill", data=tips, ax = ax[0])
sns.countplot(x="day", data=tips, ax = ax[1])
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x='day', y="total_bill", data=tips,hue="sex")
plt.show()

# %%
sns.boxplot(x='day', y="total_bill", data=tips,hue="sex")
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=5) #borderaxispad mesafeyi belirliyor
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x='day', y="total_bill", data=tips,hue="sex")
plt.show()

# %%
#width demek kutuları büyütmek veya küçültmek ile ilgili
plt.figure(figsize=(14,5))
sns.boxplot(x='day',y='total_bill',data=tips,hue='sex',width=0.3)
plt.show()

# %%
df=pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sns.boxplot(x="parental level of education",y="math score",data=df)
ploe = df["parental level of education"].value_counts()
ploe_pos = range(len(ploe.index))
plt.xticks(ploe_pos, ploe.index, rotation=45)
plt.show()

# %%
sns.boxplot(x="parental level of education",y="math score",data=df,hue="gender")
ploe = df["parental level of education"].value_counts()
ploe_pos = range(len(ploe.index))
plt.xticks(ploe_pos, ploe.index, rotation=45)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.boxplot(x='parental level of education',y='math score',data=df,hue='gender')
# Optional move the legend outside
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.xticks(rotation = 'vertical')
plt.show()

# %%
################ Boxplot Orientation ################3

# %%
#x ve y nin yerlerini değiştirince elde edebileceğimiz box plot orientation

# %% [markdown]
# ###

# %%
sns.violinplot(x="day",y="total_bill",data=tips)
plt.show()

# %%
sns.violinplot(x="day",y="total_bill",data=tips,hue="sex")
plt.show() #hue yaparak genderlara göre analiz yapılabilir

# %%
sns.violinplot(x="day",y="total_bill",data=tips,hue="sex",split=True)
plt.show() #hue yaparak genderlara göre analiz yapılabilir
#####ikisini birleştirip ölçekledik

# %%
sns.violinplot(x="day",y="total_bill",data=tips,hue="sex",inner=None)
plt.show()

# %%
sns.violinplot(x="day",y="total_bill",data=tips,hue="sex",split=True,inner="quartile")
plt.show() # Q1 ve Q3 değerlerini içerisine koyabiliyor

# %%
plt.figure(figsize=(12,6))
sns.violinplot(x="day",y="total_bill",data=tips,bw=0.2)
plt.show()#bandwith ile oynayıp hassasiyetlerin analiz edebiliriz

# %%
### Swarmplot lara geçelim

# %%
sns.swarmplot(x="day",y="total_bill",data=tips)
plt.show() #daylere göre total_bill çizdirilebilir

# %%
sns.swarmplot(x="total_bill",y="smoker",data=tips,size=7)
plt.show()

# %%
sns.swarmplot(x="total_bill",y="smoker",data=tips,size=7,hue="sex")
plt.show()#yes ve no ya göre hemde male ve female göre inceleyebiliriz

# %%
sns.swarmplot(x="total_bill",y="smoker",data=tips,size=7,hue="sex",dodge=True)
plt.show()#dodge True dersek verileri ayırabiliriz
# Out:
# C:\Users\yavuz\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.swarmplot(x="math score",data=df,size=7,dodge=True)
plt.show()#dodge True dersek verileri ayırabiliriz
# Out:
# C:\Users\yavuz\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 30.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x="math score",y="race/ethnicity",data=df,size=7,dodge=True)
plt.show()#dodge True dersek verileri ayırabiliriz
# Out:
# C:\Users\yavuz\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 35.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\yavuz\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 53.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\yavuz\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\yavuz\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x="math score",y="race/ethnicity",hue="gender",data=df,size=7,dodge=True)
plt.show()#dodge True dersek verileri ayırabiliriz
# Out:
# C:\Users\yavuz\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 41.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\yavuz\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 36.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\yavuz\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 58.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\yavuz\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 51.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.boxenplot(x="math score",y="race/ethnicity",data=df,hue="gender")
plt.show()

# %%
print(sns.get_dataset_names())
flights = sns.load_dataset("flights")
flights
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(x="year",y="passengers",data=flights)
plt.show()

# %%
flights_wide=flights.pivot(index="year",columns="month",values="passengers")
flights_wide
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
f_sum=flights.groupby(["year","month"]).sum()
f_sum
# Out:
#             passengers
# year month
# 1949 Jan           112
#      Feb           118
#      Mar           132
#      Apr           129
#      May           121
# ...                ...
# 1960 Aug           606
#      Sep           508
#      Oct           461
#      Nov           390
#      Dec           432
#
# [144 rows x 1 columns]

# %%
sns.lineplot( y = f_sum.passengers , x=f_sum.reset_index().index)
plt.show()

# %%
sns.lineplot( x="year",y="passengers",data=flights,hue="month")
plt.show()
