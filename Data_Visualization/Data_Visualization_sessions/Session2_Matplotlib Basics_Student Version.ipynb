# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ## <span style=" color:Purple"> Data Visualization Objectives</span>
#
#
# After completing this course you will be able to:
#
# -   Create Data Visualization with Python
# -   Use various Python libraries for visualization
#     - Matplotlib

# %%
# Basic Library
import numpy as np
import pandas as pd

# Libraries for Visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings;
warnings.filterwarnings('ignore')

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]

salary = [38496, 42000, 46752, 49320, 53200,
         56000, 62316, 64928, 67317, 68748, 73752]

salary_2 = [45372, 48876, 53850, 57287, 63016,
            65998, 70003, 70000, 71496, 75370, 83640]

# %% [markdown]
# # Review

# %%
# Functional 
plt.plot(age, salary)
plt.xlabel("age")
plt.ylabel("salary")
plt.title("Salary by Age");
plt.show()

# %%
# Object Oriented
fig, ax = plt.subplots(figsize=(6,3))
ax.plot(age, salary, 'r')
ax.set_xlabel('age')
ax.set_ylabel('salary')
ax.set_title('title')

plt.show()

# %%
plt.plot(age,salary,age,salary_2)

plt.show()

# %% [markdown]
# ## Subplot

# %%
plt.figure(figsize=(15,3))

plt.subplot(1,2,1)
plt.plot(age, salary, "r+", ls="--")


plt.subplot(1,2,2)
plt.plot(age, salary_2, "bo", ls=":")

plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,3))

ax[0].plot(age, salary)
ax[0].set_xlabel('age')
ax[0].set_title('First')

ax[1].plot(age, salary_2)
ax[1].set_title('Second')
ax[1].set_xlabel('age')
plt.tight_layout()

plt.show()

# %% [markdown]
# # opsiyonel

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),fontsize=18, ha='center')
    plt.title(i)

plt.suptitle("with for loop")
plt.tight_layout() 

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ## <span style=" color:Purple"> Special Plot Types</span>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <span style=" color:Purple"> Special Plot Types: Scatter Plot</span>
#
# A `scatter plot` (2D) is a useful method of comparing variables against each other. `Scatter` plots look similar to `line plots` in that they both map independent and dependent variables on a 2D graph. While the data points are connected together by a line in a line plot, they are not connected in a scatter plot. The data in a scatter plot is considered to express a trend. With further analysis using tools like regression, we can mathematically calculate this relationship and use it to predict trends outside the dataset.

# %%
x= np.array([15,17,18,17,12,17,12,19,14,11,12,19,16,13])
y= np.array([99,86,87,88,81,86,93,87,94,78,77,85,86,85])

plt.scatter(x,y)
plt.show()

# %%
y= np.random.randint(10,100,50)
x= np.random.randint(10,100,50)

plt.scatter(x,y)
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["tip"]
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
plt.scatter(tips["tip"], tips["total_bill"] );

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <span style=" color:Purple"> Special Plot Types: Bar Plot</span>

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]

fig, ax = plt.subplots()

ax.bar(langs, students)
# Out:
# <BarContainer object of 5 artists>

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
#Gunlere gore total bill

# %%
tips.groupby("day").sum()
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %%
day = tips.groupby("day").sum().index   # tips.day.unique()
day
# Out:
# CategoricalIndex(['Thur', 'Fri', 'Sat', 'Sun'], categories=['Thur', 'Fri', 'Sat', 'Sun'], ordered=False, name='day', dtype='category')

# %%
tips.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Sun', 'Sat', 'Thur', 'Fri']

# %%
day_of_total_bill = list(tips.groupby("day")["total_bill"].sum())
day_of_total_bill
# Out:
# [1096.3299999999997,
#  325.87999999999994,
#  1778.3999999999996,
#  1627.1600000000003]

# %%
fig, ax= plt.subplots(figsize =(12,7))

ax.barh(day, day_of_total_bill)
plt.show()

# %%
tipp = list(tips.groupby('day')['tip'].sum())
tipp
# Out:
# [171.83, 51.96, 260.4, 247.39000000000007]

# %%
fig, ax = plt.subplots(figsize=(10,5))


ax.bar(day, day_of_total_bill,  label="total_bill")
ax.bar(day, tipp,            label="tip")

plt.legend()

# %% [markdown]
# ### Optional

# %%
# Optional hard to coding

fig, ax = plt.subplots(figsize=(10,5))

p = np.arange(len(day))
width = 0.15

ax.bar(p - width/2, day_of_total_bill, width, label="total_bill")
ax.bar(p + width/2, tipp,           width, label="tip")

ax.set_xticks(p)
ax.set_xticklabels(day)

plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <span style=" color:Purple"> Special Plot Types: Histogram Plot</span>

# %%
x = np.random.randn(250)

# %%
plt.hist(x, bins =30)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.hist(tips["total_bill"], bins =40)
plt.show()

# %%
plt.hist(tips.tip, bins = 40)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <span style=" color:Purple"> Special Plot Types: BOX Plot</span>
#
# A `box plot` is a way of statistically representing the *distribution* of the data through five main dimensions:
#
# *   **Minimum:** The smallest number in the dataset excluding the outliers.
# *   **First quartile:** Middle number between the `minimum` and the `median`.
# *   **Second quartile (Median):** Middle number of the (sorted) dataset.
# *   **Third quartile:** Middle number between `median` and `maximum`.
# *   **Maximum:** The largest number in the dataset excluding the outliers.

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%203/images/boxplot_complete.png" width=440, align="center">

# %%
X = np.random.normal(170,10,250)

plt.boxplot(X, vert = False)
plt.show()

# %%
box = np.array(np.random.rand(10,4))
box
# Out:
# array([[0.92727455, 0.91719744, 0.78984888, 0.21081068],
#        [0.77744424, 0.14220788, 0.20848243, 0.3094447 ],
#        [0.4788636 , 0.96315147, 0.97269883, 0.79619747],
#        [0.61314919, 0.94517039, 0.1424167 , 0.37852701],
#        [0.90223247, 0.86916106, 0.34177488, 0.37204531],
#        [0.52367083, 0.5732591 , 0.67844597, 0.0947503 ],
#        [0.87553379, 0.35303883, 0.18924444, 0.0833063 ],
#        [0.04611798, 0.45233235, 0.72760652, 0.43591751],
#        [0.88102552, 0.62111614, 0.20639385, 0.52751981],
#        [0.5676272 , 0.64817993, 0.15205827, 0.55211794]])

# %%
plt.boxplot(box, labels=['A', 'B', 'C', 'D'])
plt.show()

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
plt.boxplot(tips["tip"])
plt.show()

# %%
plt.boxplot([tips.tip, tips.total_bill])
plt.show()

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
tips.iloc[:, 0:2]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
plt.boxplot(tips.iloc[:,0:2],labels=['tatol_bill', 'tip'])
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <span style=" color:Purple"> Special Plot Types: Pie Chart</span>
#
# A `pie chart` is a circular graphic that displays numeric proportions by dividing a circle (or pie) into proportional slices. You are most likely already familiar with pie charts as it is widely used in business and media. We can create pie charts in Matplotlib by passing in the `kind=pie` keyword.
#
#     .autopct = sayıların .dan sonraki sayısı(float basamak)
#     .startangle = kaç derece döndürüleceği
#     .pctdistance= sayıların ne kadar mesafeye yazılacağı
#     .explode = merkezden uzaklaşan pasta dilimleri
#     .labeldistance = birimlerin merkezden uzaklığı, "0" merkez, 1 çember (edited)

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

# %%
plt.figure(figsize=(10,8))
plt.pie(y, labels = mylabels, labeldistance = 0.7, autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(10,8))
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0, 0.2, 0, 0]

# %%
plt.figure(figsize=(10,8))
plt.pie(y, labels = mylabels, explode = myexplode, labeldistance=0.7, autopct="%.1f")
plt.legend()
plt.show()

# %% [markdown]
# The above visual is not very clear, the numbers and text overlap in some instances. Let's make a few modifications to improve the visuals:
#
# *   Remove the text labels on the pie chart by passing in `legend` and add it as a seperate legend using `plt.legend()`.
# *   Push out the percentages to sit just outside the pie chart by passing in `pctdistance` parameter.
# *   Pass in a custom set of colors for continents by passing in `colors` parameter.
# *   **Explode** the pie chart to emphasize the lowest three continents (Bananas, Apples, Dates and Cherries) by passing in `explode` parameter.

# %%
plt.figure(figsize=(10,8))


colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0, 0, 0.1, 0.1] # ratio for each continent with which to offset each wedge.


y = np.array([25, 35, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]


plt.pie(y, labels = mylabels, labeldistance=0.7, autopct="%.2f", shadow=True, startangle=90, pctdistance=1.1,textprops={'fontsize': 14}, colors=colors_list, explode=explode_list)
plt.legend()
plt.show()

# %% [markdown]
# # PANDAS VISUALIZATION

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.plot()
# Out:
# <AxesSubplot:>

# %%
tips.iloc[:,0:2].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Pandas Scatter

# %%
tips.plot.scatter(x='tip', y='total_bill')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
tips.plot(x='tip', y='total_bill', kind="scatter")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# # Pandas Bar Plot

# %%
df=pd.DataFrame(np.random.rand(5,4),	columns=['a','b','c','d'])

df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.rand(5,4),	columns=['a','b','c','d'])
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
tips.groupby("day")["tip"].sum().plot.bar(x="day",y="tip"  )
# Out:
# <AxesSubplot:xlabel='day'>

# %%
tips.groupby("sex")["tip"].sum().plot.bar(x="sex",y="tip"  )
# Out:
# <AxesSubplot:xlabel='sex'>

# %% [markdown]
# #  Pandas Histogram

# %%
tips.plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
tips[["tip","total_bill","size"]].diff().hist(bins=10)
plt.show()

# %% [markdown]
# # Pandas Box Plot

# %%
tips.plot.box();

# %%
tips.groupby("day").sum()
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %% [markdown]
# # Pandas Pie Chart

# %%
tips.groupby("day").sum().plot.pie(subplots=True,figsize=(18, 5), autopct="%.2f",labeldistance=0.8)
plt.show()

# %% [markdown]
# # Kernel Density Estimation plot

# %%
df_kde = pd.Series(np.random.randn(1000))

df_kde.plot.kde();

# %%
tips.groupby("day")["size","tip"].sum().plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Three-Dimensional Plotting in Matplotlib

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# %%
ax = plt.axes(projection='3d')
# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Reds');

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df = sns.load_dataset("tips")
groupedvalues=df.groupby('day').sum().reset_index()

pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["total_bill"].argsort().argsort() 
g=sns.barplot(x='day',y='tip',data=groupedvalues, palette=np.array(pal[::-1])[rank])

for index, row in groupedvalues.iterrows():
    g.text(row.name,row.tip, round(row.total_bill,2), color='black', ha="center")

plt.show()

# %%
palette = sns.color_palette('Blues_d', len(rank))
ax = sns.barplot(x='day', y='tip', palette=np.array(palette)[rank], data=groupedvalues)

# %%
x=[1,2,3,4,5,6,7,8,9]
y=[1,4,9,16,25,36,49,64,81]
fig,ax=plt.subplots(nrows=2,ncols=1,figsize=(8,9))
ax[0].plot(x,y)
ax[1].plot(y,x)
plt.tight_layout()

# %%
x_com = ["Amazon","Apple","Microsoft","Tesla","SpaceX"]
x_comi=np.arange(5)
y_dol = [189,211,100,192,100]
y_doli=[100,150,200,250,300]

# %%
plt.bar(x_comi,y_dol,width=0.4)
plt.bar(x_comi+0.4,y_doli,width=0.4)
plt.xticks(x_comi,x_com)
plt.show()

# %%
x_com = ["Amazon","Apple","Microsoft","Tesla","SpaceX"]
y_dol = [189,211,100,192,100]

# %%
plt.figure(figsize=(8,8))
plt.pie(y_dol,labels=x_com,startangle=90,autopct="%0.0f%%",pctdistance=0.7,textprops={"fontsize":15},explode=[0,0,0.5,0.4,0])
plt.show()

# %%
sislist=np.arange(20,46)
siselist=np.arange(1,27)
sisey=np.random.randn(0,,61,2)
plt.plot(sislist,sisey,label="kas")
plt.plot(siselist,sisey,label="goz")
plt.legend()
plt.show()
# Out:
#   File "<ipython-input-73-ccbb73cb921d>", line 3
#     sisey=np.random.randn(0,,61,2)
#                             ^
# SyntaxError: invalid syntax

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
langs=["C","C++","Java","Python","PHP"]
students=[23,17,35,29,12]
fig,ax=plt.subplots()
ax.bar(langs,students)
for i in range(len(langs)):
    plt.text(langs[i],students[i],str(students[i]),ha="center",va="bottom")

# %%
tips = sns.load_dataset("tips")
tips.head()
df=tips.groupby("day")
df

# %%
fig, ax = plt.subplots()
x = df.index
y = df.total_bill
ax.bar(x,y )
ax.set_title("Total Bill Distribution by Days")
for i in range(len(x)):
    plt.text(x[i], y[i], str(round(y[i],2)), ha="center",va="bottom") #round ile ortaya gelen rakam sayısıı sınırlandırdık

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x='total_bill',y='tip',data=tips)
ax.set(xlabel='Total Bill', ylabel='Tip', title='Some title') #bu şekilde şekli büyütür
#plt.legend(labels=['legend1'])
plt.show()

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips,hue="sex",style="sex",s=100) #hue ya göre groupby yaptık
plt.show() #s size olarak tanımlanır

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips,hue="sex", s=200, style="sex")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',size="sex", data=tips)# hue yapmadan size verisine sex atarsak
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',s=200, data=tips, alpha=1);
#sns.scatterplot(x='salary',y='sales',data=df,s=200,linewidth=0,alpha=0.2)
#sns.scatterplot(x='salary',y='sales',data=df,s=200,linewidth=0,alpha=0.2)                               #yoğunlaşmanın nerede olduğunu anlamak için transparanse parametresi kullanılıyor

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='total_bill',y='tip', data=tips,style='sex',hue='sex',s=100)
# Call savefig in the same cell
plt.savefig('example_scatter.jpg') #neredeyse oraya kayıt ediyor

# %%
##### Distrubution Plots ########## (rugplot,displot,histplot)

# %%
sns.rugplot(x="total_bill",data=tips,height=0.8)
sns.displot(x="total_bill",data=tips)
sns.displot(tips["total_bill"])

# %%
sns.histplot(x="total_bill",data=tips,kde=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.rugplot(tips["total_bill"],height=0.5)# height değeri rugplot değerlerini arttırır
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.histplot(data=tips,x="total_bill",bins=30,kde=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.set(style="whitegrid") #grid veriyoruz
sns.histplot(data=tips,x="total_bill",bins=20,kde=True)
plt.show()

# %%
sns.set_style("darkgrid", {"grid.color": "0.8", "grid.linestyle": "--"})
sns.lineplot(x=["A", "B", "C"], y=[1, 3, 2])
# Out:
# <AxesSubplot:>

# %%
sns.displot(data=tips,x="total_bill",bins=20,color="red",kde=True)

# %%
##############THE KERNEL DENSİTY ESTİMETİON PLOT#############

# %%
sns.kdeplot(tips.total_bill)#sadece kde değerleri sadece 10 veya 20 değerleri
plt.show()                              #arasına focuslanmak istediğimde

# %%
sns.kdeplot(tips.total_bill,clip=[10,20]) #10 ila 20 arasına focusladık total bill değerini
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(tips.total_bill,bw_adjust=0.3) #bandwith yapabiliriz daha 
# bw_adjust daha hassas bir şekilde inceleme imkanı bize vermiş olur
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
#altı fill edilebilir yani doldurulabilir ayrıca rengide değişebilir
sns.kdeplot(tips.total_bill,bw_adjust=0.3,shade=True,color="red")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
#2 boyutlu kde nasıl çizilir

# %%
data = pd.DataFrame(np.random.normal(0,1,size=(100,2)),columns=['x','y'])
data #bu data framein kde sini çizdirirsek
# Out:
#            x         y
# 0  -0.322937  1.326735
# 1   0.106364  1.171740
# 2  -0.244634 -1.410412
# 3   1.080042  0.574986
# 4  -1.048421 -0.163314
# ..       ...       ...
# 95 -1.438351 -1.507411
# 96  0.247767  0.765413
# 97  0.095751 -0.279920
# 98  0.244398  2.160751
# 99  0.768808 -1.661643
#
# [100 rows x 2 columns]

# %%
sns.kdeplot(data=data,x="x",y="y",cbar=True,shade=True) #2 boyutlu kde bu şekilde oluyor
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
plt.figure(figsize=(8,10))
ax=sns.scatterplot(x="total_bill",y="tip",data=tips,hue="day",s=100)
