# %%
# Basic Libraries
import pandas as pd
import numpy as np
# Libraries for visualizaton
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
titanic=sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(x="pclass",y="survived",hue="sex",data=titanic,kind="bar",estimator=np.sum,row="embarked",col="alone")

# %%
sns.catplot(x="pclass",y="survived",hue="sex",data=titanic,kind="bar",estimator=np.sum,col="sex")

# %%
####categorik veriler için

# %%
tips=sns.load_dataset("tips")
sns.catplot(x="day",y="total_bill",data=tips,kind="box")

# %%
sns.catplot(x="day",y="total_bill",data=tips,kind="box",hue="smoker")

# %%
sns.catplot(x="day",y="total_bill",data=tips,kind="violin",hue="smoker")

# %%
sns.catplot(x="day",y="total_bill",data=tips,kind="swarm",hue="smoker")

# %%
############### joinplot ortak dağılım grafiği  #######


###COmparison değerler########

# %%
sns.catplot(x="day",data=tips, kind="count",hue="smoker")

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="hex")

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="kde")

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="reg")

# %%
              #########   PAİRPLOT   ###############

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue="sex")

# %%
sns.pairplot(tips,hue="sex",palette="viridis",corner=True)

# %%
sns.pairplot(tips,hue="sex",palette="viridis",corner=True,diag_kind="hist")
###her birinin combinasyonunu alıp ilişkilerini inceler

# %%
##diag_kind : {'auto', 'hist', 'kde', None}

# %%
#####################    Pairgrid ########################

# %%
g = sns.PairGrid(tips)
g = g.map_upper(sns.scatterplot)
g = g.map_diag(sns.histplot)

# %%
g=sns.PairGrid(tips)
g.map_diag(sns.histplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot, color ="r");

# %%
g = sns.PairGrid(tips, hue="sex", palette="viridis")
g = g.map_upper(sns.scatterplot, linewidths=1, edgecolor="w", s=40)
g = g.map_diag(sns.distplot)
g = g.map_lower(sns.kdeplot)
g = g.add_legend()

# %%
a = sns.pairplot(tips)
a.map_lower(sns.kdeplot, color='purple')
a.map_upper(sns.kdeplot, color='g');

# %%
################# FACETGRID ############333

# %%
g = sns.FacetGrid(data = tips, col="time", row="smoker") 
#temelde bir çerçeve çizer
g = g.map(plt.hist, "total_bill")

# %%
g = sns.FacetGrid(data = tips, col="time", row="smoker") 
#temelde bir çerçeve çizer
g = g.map(plt.scatter, "total_bill","tip")

# %%
###############   HEATMAP ################## matrix plots 
sns.heatmap(tips.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tips.corr(),annot=True,linecolor="red",center=True,vmax=True,cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
sns.clustermap()

# %%
iris = sns.load_dataset("iris")
species = iris.pop("species")
sns.clustermap(iris)

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.heatmap(penguins.isnull()) #datayı görselleştirme
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x="species",y="bill_length_mm",data=penguins) 
#burun uzunluklarını species e göre sınıflandırdık

# %%
sns.catplot(x="species",y="bill_length_mm",data=penguins,kind="bar",hue="sex",col="island")

# %%
sns.catplot(x="species",y="bill_length_mm",data=penguins,kind="bar",col="island",row="sex")

# %%
#yukarıda mean değerlerini görüyorduk şimdi ise

# %%
sns.catplot(x="species",y="bill_length_mm",data=penguins,kind="box",col="island",row="sex")

# %%
#şimdi mean değeri median değeri hepsini görebiliyoruz

# %%
sns.jointplot(x='flipper_length_mm',y='body_mass_g',data=penguins)  # kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# %%
#boy uzunluklarına göre burun uzunluklarını scatter etmiş haldeyiz

# %%
sns.jointplot(x='flipper_length_mm',y='body_mass_g',data=penguins, kind="reg")

# %%
sns.jointplot(x='flipper_length_mm',y='body_mass_g',data=penguins, hue="species")

# %%
#hue değerinide species olarak aldık
